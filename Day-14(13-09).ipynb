# %% [markdown]
# **VISUALIZATION of data using matplotlib**

# %% [markdown]
# **Magical function in jupyter notebook**

# %%
# %matplotlib notebook

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
plt.plot?

# %%
plt.plot()
# Out:
# <img src="data:image/png;base64,..." width="421.8181726755191">
# []

# %%
plt.plot(2,3,'o')

# %%
plt.plot(3,4,'s')

# %%
plt.plot(4,1,'v')

# %%
plt.plot(5,5,'d')

# %%
plt.plot(5,6,'or')

# %%
plt.plot(6,6,'p')

# %%
plt.plot(1,1,'1')

# %%
plt.plot(6,5,'.')

# %%
plt.plot(6,3,',')

# %%
plt.plot(5,2,'4')

# %%
plt.plot(6,3,'^')

# %%
plt.title("Line equation")
# Out:
# Text(0.5, 1, 'Line equation')

# %%
plt.xlabel("X-axis")
# Out:
# Text(0.5, 2.9214448328812876, 'X-axis')

# %%
plt.ylabel("Y-axis")
# Out:
# Text(31.46944533785184, 0.5, 'Y-axis')

# %%
x=[1,2,3,4,5,6]
y=[1,4,9,16,25,36]

# %%
plt.figure()
plt.plot(x,y,'or')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Number Squares")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="257.2727216964912">

# %%
plt.figure()
plt.plot(x,y,'d-')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Number Squares")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="228.18181323611057">

# %%
plt.figure()
plt.plot(x,y,'s--')
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Number Squares")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="231.81817679365815">

# %% [markdown]
# **Scatter plots**

# %%
colors=['red','orange']*3
colors.extend(['green','blue'])
colors
# Out:
# ['red', 'orange', 'red', 'orange', 'red', 'orange', 'green', 'blue']

# %%
plt.figure()
x=[1,2,3,4,5,6,7,8]
y=x
plt.scatter(x,y,c=colors)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="294.5454481613539">

# %% [markdown]
# **Draw the plot x and y value(y=mx+c)**

# %%
plt.figure()
x=[1,2,3,4,7,10]
y=[(2*i)+5 for i in x]
plt.plot(x,y,'-r')
# Out:
# <img src="data:image/png;base64,..." width="309.9999932809311">

# %%
orange_width=[1,2,3,4,5]
orange_height=[4,5,6,7,8]
mango_height=[6,7,8]
mango_width=[8,9,10]
plt.figure()
plt.scatter(orange_width,orange_height,label="orange")
plt.scatter(mango_width,mango_height,label="mango")
plt.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
